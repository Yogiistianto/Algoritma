# %%
#Nasted if

# %%
#if condition_1:
#    if condition_1_a:
#        ...
#    elif condition_1_b:
#        ...
#    else:
#        ...
#elif condition_2:
#    if condition_2_a:
#        ...
#    else:
#        ...
#elif condition_3:
#    if condition_3_a:
#        ...
#else:
#    ...

# %%
#Exanple (Number Chracker)

num = 10

if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")
# Out:
# Positive

# %%
#Example (Age calssifer)

age = 62

if age >= 60:
    print("You are a senior citizen")
else:
    if age >= 18:
        print("You are an adult")
    else:
        print("You are a minor")
# Out:
# You are a senior citizen

# %%
#Exercise 1

tahun = int(input("masukkan tahun: "))

if tahun % 4 == 0:
    if tahun % 100 == 0:
        if tahun % 400 == 0:
            print(f"Tahun {tahun} adalah tahun kabisat.\n")
        else:
            print(f"Tahun {tahun} bukan tahun kabisat.\n")
    else:
        print(f"Tahun {tahun} adalah tahun kabisat.\n")
else:
    print(f"Tahun {tahun} bukan tahun kabisat.\n")
# Out:
# masukkan tahun: 2026
# Tahun 2026 bukan tahun kabisat.

# %%
#Exercise 2

print("Mencari  nilai terbesar dari 3 angka")

num1 = float(input("Masukkan angka pertama  : "))
num2 = float(input("Masukkan angka kedua    : "))
num3 = float(input("Masukkan  angka ketiga  : "))


if num1 >= num2 and num1 >= num3:
    largest = num1
elif num2 >= num1 and num2 >= num3:
    largest = num2
else:
    largest = num3

print(f"Angka pertama   : {num1}")
print(f"Angka kedua     : {num2}")
print(f"Angka ketiga    : {num3}\n")
print(f"Angka terbesar adalah: {largest}\n")
# Out:
# Mencari  nilai terbesar dari 3 angka
# Masukkan angka pertama  : 50
# Masukkan angka kedua    : 24
# Masukkan  angka ketiga  : 48
# Angka pertama   : 50.0
# Angka kedua     : 24.0
# Angka ketiga    : 48.0
#
# Angka terbesar adalah: 50.0

# %%
#Exercise 3

print("Kalkulator Pembayaran Pusat Belanja")

customer_type = input("Apakah anda member? (ya/tidak): ")

total_purchase = float(input("Masukkan total jumlah pembelian: \n"))

discount_percentage = 0

if total_purchase > 100000:
    discount_percentage = 3
    if total_purchase > 200000:
        discount_percentage = 4

if customer_type.lower() == "ya":
    discount_percentage += 2

discount_amount = (discount_percentage / 100) * total_purchase

total_payment = total_purchase - discount_amount

print(f"Total Pembelian     : Rp {total_purchase:.2f}")
print(f"Presentase Diskon   : {discount_percentage}%")
print(f"Jumlah Diskon       : Rp {discount_amount:.2f}")
print(f"Total Pembayaran    : Rp {total_payment:.2f}")
# Out:
# Kalkulator Pembayaran Pusat Belanja
# Apakah anda member? (ya/tidak): ya
# Masukkan total jumlah pembelian:
# 126740
# Total Pembelian     : Rp 126740.00
# Presentase Diskon   : 5%
# Jumlah Diskon       : Rp 6337.00
# Total Pembayaran    : Rp 120403.00

# %%
#Exercise 4

print("New user")

username =  input("username : ")
email =     input("email    : ")
password =  input("password : ")

if username == "":
    print("Error: Harap isi bagian username.\n")
elif "@" not in email:
    print("Error: Email harus terdapat simbol '@'.\n")
elif len(password) < 8:
    print("Error: Password harus lebih dari 8 karakter.\n")
else:
    print("Pembuatan user baru berhasil!")
    print(f"Username: {username}")
    print(f"Email: {email}")
    print(f"Password: (password disembunyikan)")
# Out:
# New user
# username : Halo rek!
# email    : hallo@.com
# password : 123456789
# Pembuatan user baru berhasil!
# Username: Halo rek!
# Email: hallo@.com
# Password: (password disembunyikan)
