# %%
with open('biodata.txt', 'w') as file:
    file.write("Nama: Muhammad Yogi Istianto Wibowo\n")
    file.write("Program Studi: Teknologi Informasi\n")
    file.write("NPM: 2410506006\n")
    file.write("Alamat: Glagah RT2/RW4, Mertoyudan, Banjarnegoro\n")
    file.write("Hobi: Olahraga\n")
    file.write("Email: yogiskarton@gmail.com")

# %%
with open('biodata.txt', 'r') as file:
    for line in file:
        if line.startswith("Nama:"):
            nama = line.split(":")[1].strip()
        elif line.startswith("Program Studi:"):
            program_studi = line.split(":")[1].strip()
        elif line.startswith("Email:"):
            email = line.split(":")[1].strip()

    print("Nama:", nama)
    print("Program Studi:", program_studi)
    print("Email:", email)
# Out:
# Nama: Muhammad Yogi Istianto Wibowo
# Program Studi: Teknologi Informasi
# Email: yogiskarton@gmail.com

# %%
with open('biodata.txt', 'r') as file:
    data = []
    for line in file:
        if line.startswith("Nama:"):
            nama = line.split(":")[1].strip()
        elif line.startswith("NPM:"):
            npm = line.split(":")[1].strip()
        elif line.startswith("Program Studi:"):
            program_studi = line.split(":")[1].strip()
        elif line.startswith("Alamat:"):
            alamat = line.split(":")[1].strip()
            data.append((nama, npm, program_studi, alamat))

with open('data_baru.txt', 'w') as file:
    for item in data:
        file.write(f"{item[0]}, {item[1]}, {item[2]}, {item[3]}\n")

# %%
with open('data_baru.txt', 'r') as file:
    for line in file:
        if line.startswith("Nama:"):
            nama = line.split(":")[1].strip()
        elif line.startswith("NPM:"):
            program_studi = line.split(":")[1].strip()
        elif line.startswith("Program Studi:"):
            email = line.split(":")[1].strip()
        elif line.startswith("Alamat:"):
            email = line.split(":")[1].strip()

    print("Nama:", nama)
    print("NPM:", npm)
    print("Program Studi:", program_studi)
    print("Alamat:", alamat)
# Out:
# Nama: Muhammad Yogi Istianto Wibowo, 2410506006, Teknologi Informasi, Glagah RT2/RW4, Mertoyudan, Banjarnegoro
# NPM: 2410506006
# Program Studi: 2410506006
# Alamat: Glagah RT2/RW4, Mertoyudan, Banjarnegoro
