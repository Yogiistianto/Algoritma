# %%
print('Hello, Python!')
# Out:
# Hello, Python!

# %%
print("Universitas Tidar")
# Out:
# Universitas Tidar

# %%
import sys
print(sys.version)
# Out:
# 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]

# %%
print('Hello, Python!')
print('Hi')
# Out:
# Hello, Python!
# Hi

# %%
frint("Hello, Python!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-92b84426a1cf> in <cell line: 1>()
# ----> 1 frint("Hello, Python!")
#
# NameError: name 'frint' is not defined

# %%
print("Hello, Python!)
# Out:
#   File "<ipython-input-11-c10a1b330477>", line 1
#     print("Hello, Python!)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("This will be printed")
frint("This will cause an error")
print("This will NOT be printed")
# Out:
# This will be printed
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-aa3f0d14d353> in <cell line: 2>()
#       1 print("This will be printed")
# ----> 2 frint("This will cause an error")
#       3 print("This will NOT be printed")
#
# NameError: name 'frint' is not defined

# %%
print("Nama         : Muhammad Yogi Istianto Wibowo")
print("")
print("NPM          : 2410506006")
print("")
print("Alamat       : Glagah")
print("")
print("Tinggi Badan : 174")
print("")
print("Berat Badan  : 55")
# Out:
# Nama         : Muhammad Yogi Istianto Wibowo
#
# NPM          : 2410506006
#
# Alamat       : Glagah
#
# Tinggi Badan : 174
#
# Berat Badan  : 55

# %%
print ("\033[1mUNIVERSITAS TIDAR\033[0m")
print("Universitas Tidar merupakan Perguruan Tinggi Pemerintah atau Perguruan Tinggi Negeri yang telah ditetapkan berdasarkan Peraturan Presiden Republik Indonesia Nomor 23 Tahun 2014 pada tanggal 1 April 2014.")
print("")
print("\033[1mJURUSAN TEKNIK ELEKTRO, MEKATRONIKA DAN INFORMASI\033[0m")
print("Jurusan Teknik Elektro terdiri atas tiga program studi, antara lain :")
print("")
print("    1. Teknik Elektro \x1B[3m(Bachelor of Elecrtical Engineering)\x1B[0m")
print("    2. Teknik Telekomunikasi \x1B[3m(Bachelor of Information Technology)\x1B[0m")
print("    3. Teknik Elektro Mekatronika \x1B[3m(Bachelor of Mechatronics Engineering)\x1b[0m")
# Out:
# UNIVERSITAS TIDAR
# Universitas Tidar merupakan Perguruan Tinggi Pemerintah atau Perguruan Tinggi Negeri yang telah ditetapkan berdasarkan Peraturan Presiden Republik Indonesia Nomor 23 Tahun 2014 pada tanggal 1 April 2014.
#
# JURUSAN TEKNIK ELEKTRO, MEKATRONIKA DAN INFORMASI
# Jurusan Teknik Elektro terdiri atas tiga program studi, antara lain :
#
#     1. Teknik Elektro (Bachelor of Elecrtical Engineering)
#     2. Teknik Telekomunikasi (Bachelor of Information Technology)
#     3. Teknik Elektro Mekatronika (Bachelor of Mechatronics Engineering)
