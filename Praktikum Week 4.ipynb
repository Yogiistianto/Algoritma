# %%
#Quiz

rating = 8.5
if rating > 8:
    print ("this album is amazing")
# Out:
# this album is amazing

# %%
#Quiz

rating = 8.5
if rating > 8:
    print ("this albumn is amazing")
else:
    print ("this album is ok")
# Out:
# this albumn is amazing

# %%
#Quiz

album_year = 1970
if album_year < 1980 or album_year == 1991 or album_year == 1993:
    print("this album came out already")
# Out:
# this album came out already

# %%
#Weekly Exercise 1

umur = 15
if umur < 17:
    print("Tidak Boleh Membuat SIM")
elif umur >= 17:
    print("Boleh Membuat SIM")
# Out:
# Tidak Boleh Membuat SIM

# %%
#Weekly Exercise 1

umur = 20
if umur < 17:
    print("Tidak Boleh Membuat SIM")
elif umur >= 17:
    print("Boleh Membuat SIM")
# Out:
# Boleh Membuat SIM

# %%
#Weekly Exercise 2

nilai = 75
if nilai >= 90:
    print("A")
elif nilai >= 80:
    print("B+")
elif nilai >= 70:
    print("B")
elif nilai >= 60:
    print("C+")
elif nilai >= 50:
    print("C")
elif nilai >= 40:
    print("D")
else:
    if nilai < 40:
        print("E")
# Out:
# B

# %%
#Weekly Exercise 3

nilai = 70
if 80.00 <= nilai <= 100.00:
    print("A")
elif 77.50 <= nilai <= 79.99:
    print("A-")
elif 75.00 <= nilai <= 77.49:
    print("A/B")
elif 72.50 <= nilai <= 74.99:
    print("B+")
elif 70.00 <= nilai <= 72.49:
    print("B")
elif 67.50 <= nilai <= 69.99:
    print("B-")
elif 65.00 <= nilai <= 67.49:
    print("B/C")
elif 62.50 <= nilai <= 64.99:
    print("C+")
elif 60.00 <= nilai <= 62.49:
    print("C")
elif 55.50 <= nilai <= 59.99:
    print("C-")
elif 50.00 <= nilai <= 54.99:
    print("C/D")
elif 45.50 <= nilai <= 49.99:
    print("D+")
elif 45.00 <= nilai <= 49.99:
    print("D")
else:
    if nilai < 40:
        print("E")
# Out:
# B
